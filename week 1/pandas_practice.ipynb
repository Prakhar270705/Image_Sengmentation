# %%
import pandas as pd
df=pd.read_csv("C:/Users/adars/Downloads/medical-charges.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df['smoker'] = df['smoker'].replace({'yes': 1, 'no': 0})

# %%
df.head()
# Out:
#    age     sex     bmi  children  smoker     region      charges
# 0   19  female  27.900         0       1  southwest  16884.92400
# 1   18    male  33.770         1       0  southeast   1725.55230
# 2   28    male  33.000         3       0  southeast   4449.46200
# 3   33    male  22.705         0       0  northwest  21984.47061
# 4   32    male  28.880         0       0  northwest   3866.85520

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker        int64
# region       object
# charges     float64
# dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['smoker'],df['charges'],alpha=0.5)

# %%
plt.bar(df['age'],df['charges'])
# Out:
# <BarContainer object of 1338 artists>

# %%
plt.hist(df['charges'])
# Out:
# (array([536., 398., 129.,  86.,  35.,  59.,  57.,  32.,   2.,   4.]),
#  array([ 1121.8739  ,  7386.729311, 13651.584722, 19916.440133,
#         26181.295544, 32446.150955, 38711.006366, 44975.861777,
#         51240.717188, 57505.572599, 63770.42801 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.bar(df['bmi'],df['charges'],alpha=0.5)
# Out:
# <BarContainer object of 1338 artists>

# %%
len(df[df['charges']==1200])
# Out:
# 0

# %%
df['charges'].min()
# Out:
# 1121.8739

# %%
plt.bar(df['region'],df['charges'],alpha=0.5)
# Out:
# <BarContainer object of 1338 artists>

# %%
plt.scatter(df['bmi'],df['charges'],alpha=0.5)
